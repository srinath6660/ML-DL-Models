# %%
import numpy as np
import pandas as pd

# %%
content = pd.read_csv('Games.csv')

# %%
content
# Out:
#                                                      URL          ID  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427   284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400   284926400
# 2      https://apps.apple.com/us/app/morocco/id284946595   284946595
# 3      https://apps.apple.com/us/app/sudoku-free/id28...   285755462
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...   285831220
# ...                                                  ...         ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  1474626442
# 17003  https://apps.apple.com/us/app/eachother/id1474...  1474919257
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  1474962324
# 17005  https://apps.apple.com/us/app/fatall/id1474963671  1474963671
# 17006  https://apps.apple.com/us/app/the-three-kingdo...  1475076711
#
#                             Name                        Subtitle  \
# 0                         Sudoku                             NaN
# ...

# %%
#REMOVING NULL VALUES::
content = content.dropna()

# %%
content
# Out:
#                                                      URL          ID  \
# 5      https://apps.apple.com/us/app/sudoku-classic-n...   286210009
# 19     https://apps.apple.com/us/app/cool-sudoku-jigs...   290614255
# 75     https://apps.apple.com/us/app/gun-runner/id306...   306165224
# 90     https://apps.apple.com/us/app/uniwar-multiplay...   311456818
# 106    https://apps.apple.com/us/app/towermadness/id3...   316491616
# ...                                                  ...         ...
# 16828  https://apps.apple.com/us/app/zipline-valley/i...  1470146913
# 16842  https://apps.apple.com/us/app/lordz2-io-conque...  1470369387
# 16856  https://apps.apple.com/us/app/smartphone-tycoo...  1470806544
# 16863  https://apps.apple.com/us/app/hero-chess-teamf...  1471007235
# 16932  https://apps.apple.com/us/app/spatula-tft-chea...  1472818549
#
#                                  Name                        Subtitle  \
# ...

# %%
#highrating
high_rating = content[content.AUR==5.000000]

# %%
high_rating
# Out:
#                                                      URL          ID  \
# 1431   https://apps.apple.com/us/app/conceptis-sudoku...   537201666
# 1649   https://apps.apple.com/us/app/bloons-td-5/id56...   563718995
# 1672   https://apps.apple.com/us/app/conceptis-hashi/...   567583852
# 1789   https://apps.apple.com/us/app/conceptis-nurika...   581912445
# 1951   https://apps.apple.com/us/app/simply-sudoku/id...   600521463
# ...                                                  ...         ...
# 16740  https://apps.apple.com/us/app/sudoku-classic-p...  1467609353
# 16748  https://apps.apple.com/us/app/flip-it-up/id146...  1467734379
# 16758  https://apps.apple.com/us/app/chess-fighters-b...  1468072585
# 16791  https://apps.apple.com/us/app/bounce-back-focu...  1469258384
# 16932  https://apps.apple.com/us/app/spatula-tft-chea...  1472818549
#
#                                  Name                        Subtitle  \
# ...

# %%
#ratingabove4
rating=content[content.AUR>=4.000000]

# %%
rating
# Out:
#                                                      URL          ID  \
# 106    https://apps.apple.com/us/app/towermadness/id3...   316491616
# 118      https://apps.apple.com/us/app/chess/id319305999   319305999
# 127    https://apps.apple.com/us/app/pixel-starships/...   321756558
# 128      https://apps.apple.com/us/app/pushy/id322110989   322110989
# 156    https://apps.apple.com/us/app/chess-play-learn...   329218549
# ...                                                  ...         ...
# 16789  https://apps.apple.com/us/app/idle-industry-wo...  1469202567
# 16791  https://apps.apple.com/us/app/bounce-back-focu...  1469258384
# 16828  https://apps.apple.com/us/app/zipline-valley/i...  1470146913
# 16863  https://apps.apple.com/us/app/hero-chess-teamf...  1471007235
# 16932  https://apps.apple.com/us/app/spatula-tft-chea...  1472818549
#
#                              Name                        Subtitle  \
# 106                  TowerMadness        Classic Defense Strategy
# ...

# %%
#freeapps
price_free = content[content.Price==0]

# %%
price_free
# Out:
#                                                      URL          ID  \
# 5      https://apps.apple.com/us/app/sudoku-classic-n...   286210009
# 19     https://apps.apple.com/us/app/cool-sudoku-jigs...   290614255
# 75     https://apps.apple.com/us/app/gun-runner/id306...   306165224
# 90     https://apps.apple.com/us/app/uniwar-multiplay...   311456818
# 118      https://apps.apple.com/us/app/chess/id319305999   319305999
# ...                                                  ...         ...
# 16828  https://apps.apple.com/us/app/zipline-valley/i...  1470146913
# 16842  https://apps.apple.com/us/app/lordz2-io-conque...  1470369387
# 16856  https://apps.apple.com/us/app/smartphone-tycoo...  1470806544
# 16863  https://apps.apple.com/us/app/hero-chess-teamf...  1471007235
# 16932  https://apps.apple.com/us/app/spatula-tft-chea...  1472818549
#
#                                  Name                        Subtitle  \
# ...

# %%
#paidapps
price_paid = content[content.Price >1.00]

# %%
price_paid
# Out:
#                                                      URL          ID  \
# 106    https://apps.apple.com/us/app/towermadness/id3...   316491616
# 128      https://apps.apple.com/us/app/pushy/id322110989   322110989
# 180    https://apps.apple.com/us/app/catan-classic/id...   335029050
# 309    https://apps.apple.com/us/app/towermadness-hd/...   368841090
# 323    https://apps.apple.com/us/app/blood-honor-no-a...   373002953
# ...                                                  ...         ...
# 15279  https://apps.apple.com/us/app/papas-pancakeria...  1438245901
# 15352  https://apps.apple.com/us/app/rebel-inc/id1439...  1439187947
# 16079  https://apps.apple.com/us/app/papas-wingeria-t...  1451873044
# 16305  https://apps.apple.com/us/app/santorini-board-...  1456647343
# 16548  https://apps.apple.com/us/app/papas-donuteria-...  1462324486
#
#                              Name                        Subtitle  \
# 106                  TowerMadness        Classic Defense Strategy
# ...

# %%
price_rating= content[['AUR','Price']]

# %%
price_rating
# Out:
#        AUR  Price
# 5      3.0   0.00
# 19     3.5   0.00
# 75     2.5   0.00
# 90     3.5   0.00
# 106    4.0   2.99
# ...    ...    ...
# 16828  4.5   0.00
# 16842  3.0   0.00
# 16856  2.5   0.00
# 16863  4.5   0.00
# 16932  5.0   0.00
#
# [1935 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
#ratingvsprice
plt.plot(content.AUR , content.Price)
plt.xlabel('Rating')
plt.ylabel('Price')
plt.show()

# %%
rating_count= content[['AUR','URC']]

# %%
rating_count
# Out:
#        AUR      URC
# 5      3.0     47.0
# 19     3.5    357.0
# 75     2.5   5462.0
# 90     3.5  14073.0
# 106    4.0  42389.0
# ...    ...      ...
# 16828  4.5     14.0
# 16842  3.0     17.0
# 16856  2.5     29.0
# 16863  4.5     51.0
# 16932  5.0     11.0
#
# [1935 rows x 2 columns]

# %%
plt.plot(content.AUR , content.URC)
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()
